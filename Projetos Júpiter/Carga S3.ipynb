# %%
import boto3
import pandas as pd

# %%
#Login AWS
client = boto3.client('s3',
                        aws_access_key_id = 'meu_acesso_meu_acesso_meu_acesso',
                        aws_secret_access_key = 'minha_chave_minha_chave')

# %%
#Dowload AWS files

s3 = boto3.client("s3")
s3.download_file(
    Bucket="projetas-teste", Key="s3://projetas-teste/Inbound-zone/AIR_CIA/", Filename="s3://projetas-teste/Inbound-zone/AIR_CIA/ANAC_20211220_203627.csv"
)

s3.download_file(
    Bucket="projetas-teste", Key="s3://projetas-teste/Inbound-zone/VRA/", Filename="s3://projetas-teste/Inbound-zone/VRA/"
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# c:\Users\Weirivelton\Desktop\Teste projetas\Tratamento de dados\Projetos Júpiter\Carga S3.ipynb Célula: 3 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Weirivelton/Desktop/Teste%20projetas/Tratamento%20de%20dados/Projetos%20J%C3%BApiter/Carga%20S3.ipynb#ch0000002?line=0'>1</a> #Dowload  AWS csv
#       <a href='vscode-notebook-cell:/c%3A/Users/Weirivelton/Desktop/Teste%20projetas/Tratamento%20de%20dados/Projetos%20J%C3%BApiter/Carga%20S3.ipynb#ch0000002?line=2'>3</a> s3 = boto3.client("s3")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Weirivelton/Desktop/Teste%20projetas/Tratamento%20de%20dados/Projetos%20J%C3%BApiter/Carga%20S3.ipynb#ch0000002?line=3'>4</a> s3.download_file(
# ...

# %%
#Upload AWS tabela VAR

file1 = "VRA.csv"
file = r'C:\Users\Weirivelton\Desktop\Teste projetas\Tratamento de dados\Bases tratadas\var.csv'
upload_file_bucket = 'projetas-teste'
upload_file_key = 'raw-zone/' + str(file1)
client.upload_file(file, upload_file_bucket, upload_file_key)
print("Upload Base VRA com sucesso!")

#Upload AWS tabela AIR_CIA

file2 = "AIR_CIA.csv"
file = r'C:\Users\Weirivelton\Desktop\Teste projetas\Tratamento de dados\Bases tratadas\AIR_CIA.csv'
upload_file_bucket = 'projetas-teste'
upload_file_key = 'raw-zone/' + str(file2)
client.upload_file(file, upload_file_bucket, upload_file_key)
print("Upload Base AIR CIA com sucesso!")

#Upload AWS tabela DIM_GEOGRÁFICA

file3 = "dim_geográfica.csv"
file = r'C:\Users\Weirivelton\Desktop\Teste projetas\Tratamento de dados\Bases tratadas\dim_geográfica.csv'
upload_file_bucket = 'projetas-teste'
upload_file_key = 'raw-zone/' + str(file3)
client.upload_file(file, upload_file_bucket, upload_file_key)
print("Upload Base AIR CIA com sucesso!")

#Upload AWS tabela API_BASE

file4 = "api_base.csv"
file = r'C:\Users\Weirivelton\Desktop\Teste projetas\Tratamento de dados\Bases tratadas\api_base.csv'
upload_file_bucket = 'projetas-teste'
upload_file_key = 'raw-zone/' + str(file4)
client.upload_file(file, upload_file_bucket, upload_file_key)
print("Upload Base API_BASE com sucesso!")
# Out:
# Upload Base VRA com sucesso!
# Upload Base AIR CIA com sucesso!
# Upload Base AIR CIA com sucesso!
# Upload Base API_BASE com sucesso!
