# %%
import os
import glob
import pandas as pd
import boto3
import os

# %%
#Upload csv

base1 =pd.read_csv("C:\\Users\\Weirivelton\\Desktop\Teste projetas\\Tratamento de dados\\Arquivos CSV\\ANAC_20211220_203627.csv", delimiter=';' , encoding='utf-8')
base2 =pd.read_csv("C:\\Users\\Weirivelton\\Desktop\Teste projetas\\Tratamento de dados\\Arquivos CSV\\ANAC_20211220_203643.csv", delimiter=';' , encoding='utf-8')
base3 =pd.read_csv("C:\\Users\\Weirivelton\\Desktop\Teste projetas\\Tratamento de dados\\Arquivos CSV\\ANAC_20211220_203733.csv", delimiter=';' , encoding='utf-8')

# %%
#Tratamento dos dados (Concatenar bases)
base_geral = pd.concat([base1,base2,base3])
df = pd.DataFrame(base_geral)

#Tratamento dos dados (Renomear colunas em snake_case)
df.rename(columns={'ICAO IATA': 'ICAO_IATA' ,   
                     'RazÃ£o Social' :'Razao_Social',
                     'Atividades AÃ©reas' :'Atividades_Aereas',
                    'EndereÃ§o Sede' : 'Endereco_Sede',
                    'DecisÃ£o Operacional': 'Decicao_Operacional',
                   'Data DecisÃ£o Operacional' : 'Data_Decisao_Operacional',
                   'Validade Operacional': 'Validade_Operacional',
                    'E-Mail' : 'EMail',
                    'Telefone' : 'Telefone',
                    'CNPJ' : 'CNPJ'
                  
                   
                    }, inplace = True)

#Tratamento dos dados (Separação coluna "ICAO_IATA" )
df2 = df
df2 ["id_icao"] =df.ICAO_IATA.apply(lambda x: str(x)[:3])
df2 ["IATA"] =df.ICAO_IATA.apply(lambda x: str(x)[4:])

#Exluir coluna "ICAO_IATA"
df2 = df2.drop(columns=['ICAO_IATA'])

# %%
df2.dropna(subset=['id_icao'], inplace=True)
df2.dropna(subset=['EMail'], inplace=True)
df2.dropna(subset=['Validade_Operacional'], inplace=True)
df2.drop_duplicates(subset='id_icao')
# Out:
#                             Razão Social                CNPJ  \
# 0     ABSA - AEROLINHAS BRASILEIRAS S.A.  00.074.635/0001-33
# 5     AZUL LINHAS AÉREAS BRASILEIRAS S/A  09.296.295/0001-60
# 7           MAP TRANSPORTES AÉREOS LTDA.  10.483.635/0001-40
# 8   MODERN TRANSPORTE AEREO DE CARGA S.A  03.887.831/0001-15
# 10           SIDERAL LINHAS AÉREAS LTDA.  10.919.908/0001-57
# 11                TAM LINHAS AÉREAS S.A.  02.012.862/0001-60
# 12              TOTAL LINHAS AÉREAS S.A.  32.068.363/0001-55
# 2                   OMNI TÁXI AÉREO S.A.  03.670.763/0001-38
# 3                    PRIME TÁXI AIR LTDA  23.568.370/0001-25
# 1     RTS - ROTA DO SOL TÁXI AÉREO LTDA.  01.904.715/0001-31
#
#                                     Atividades Aéreas  \
# 0                            TRANSPORTE AÉREO REGULAR
# 5                            TRANSPORTE AÉREO REGULAR
# 7                            TRANSPORTE AÉREO REGULAR
# 8                            TRANSPORTE AÉREO REGULAR
# ...

# %%
#upload para CSV
df2.to_csv( "C:\\Users\\Weirivelton\Desktop\Teste projetas\\Tratamento de dados\\Bases tratadas\\AIR_CIA.csv" , index = False ,  encoding='UTF-8' )

# %%
df3 = pd.DataFrame(df2, columns=['id_icao' , 'Endereço Sede'])
df4 [['Rua', 'Cidade', 'nova']]= df3['Endereço Sede'].str.split(',',  expand = True , n=2)
df4['nova'].str.split('-',  expand = True , n=1)
# Out:
#                                                     0  \
# 0   AEROPORTO INTERNACIONAL DE VIRACOPOS, RODOVIA ...
# 5   AV. MARCOS PENTEADO ULHÔA RODRIGUES,N°939, 9° ...
# 7   AVENIDA SANTOS DUMONT, Nº 1350, AEROPORTO INTE...
# 8   AVENIDA PREFEITO LUIZ LATORRE, Nº 9450, CONDOM...
# 10                          RODOVIA CONTORNO LESTE BR
# 11  RUA ÁTICA , N° 673, 6ª ANDAR, SALA 62, JARDIM ...
# 12            AV. SENADOR SALGADO FILHO, 5397 SALA D
# 2              AV. AYRTON SENNA, 2541 RUA F1 LOTE 40
# 3                                 AL. RIO NEGRO, 585
# 4                           RODOVIA CONTORNO LESTE BR
# 1   PRAÇA EDUARDO GOMES, S/Nº, TERMINAL DE AVIAÇÃO...
#
#                                                     1  \
# 0                                       970, CAMPINAS
# 5                                     TAMBORÉ, 06.460
# 7                        SAGUÃO DE EMBARQUE DO TPS I
# 8                                        430, JUNDIAÍ
# ...

# %%
#Login AWS
client = boto3.client('s3',
                        aws_access_key_id = 'AKIAVAK55RUFNI2ZYAEC',
                        aws_secret_access_key = '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')

# %%
#Upload AWS

file2 = "AIR_CIA.csv"
file = r'C:\Users\Weirivelton\Desktop\Teste projetas\Tratamento de dados\Bases tratadas\AIR_CIA.csv'
upload_file_bucket = 'projetas-teste'
upload_file_key = 'raw-zone/' + str(file2)
client.upload_file(file, upload_file_bucket, upload_file_key)
print("Upload Successful")
# Out:
# Upload Successful

# %%
df2.head(2)
# Out:
#                           Razão_Social                CNPJ  \
# 0   ABSA - AEROLINHAS BRASILEIRAS S.A.  00.074.635/0001-33
# 5  AZUL LINHAS AÃREAS BRASILEIRAS S/A  09.296.295/0001-60
#
#            Atividades_Aéreas  \
# 0  TRANSPORTE AÃREO REGULAR
# 5  TRANSPORTE AÃREO REGULAR
#
#                                        Endereço_Sede  \
# 0  AEROPORTO INTERNACIONAL DE VIRACOPOS, RODOVIA ...
# 5  AV. MARCOS PENTEADO ULHÃA RODRIGUES,NÂ°939, 9...
#
#                                         Telefone                        EMail  \
# 0                                 (11) 5582-8055               gar@tam.com.br
# 5   (55) (11) 4134-9887 | Fax: (55)(11)4134-9890  vanessa.reis@voeazul.com.br
#
#   Decição_Operacional Data_Decisão_Operacional Validade_Operacional id_icao  \
# 0     DECISÃO NÂº 41               22/04/2015           23/04/2025     LTG
# 5    DecisÃ£o nÂº 178               20/11/2018           21/11/2028     AZU
#
#   IATA
# 0   M3
# 5   AD
