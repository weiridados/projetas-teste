# %%
import pandas as pd
import json
from pandas import json_normalize
import numpy  as np
import boto3

# %%
arquivo1= pd.read_json("C:\\Users\Weirivelton\\Desktop\\Teste projetas\\Tratamento de dados\\Arquivos Json\\VRA_20211.json", encoding='utf-8-sig')
arquivo2= pd.read_json("C:\\Users\Weirivelton\\Desktop\\Teste projetas\\Tratamento de dados\\Arquivos Json\\VRA_202110.json", encoding='utf-8-sig')
arquivo3= pd.read_json("C:\\Users\Weirivelton\\Desktop\\Teste projetas\\Tratamento de dados\\Arquivos Json\\VRA_20211.json", encoding='utf-8-sig')
arquivo4= pd.read_json("C:\\Users\Weirivelton\\Desktop\\Teste projetas\\Tratamento de dados\\Arquivos Json\\VRA_20212.json", encoding='utf-8-sig')
arquivo5= pd.read_json("C:\\Users\Weirivelton\\Desktop\\Teste projetas\\Tratamento de dados\\Arquivos Json\\VRA_20213.json", encoding='utf-8-sig')
arquivo7= pd.read_json("C:\\Users\Weirivelton\\Desktop\\Teste projetas\\Tratamento de dados\\Arquivos Json\\VRA_20214.json", encoding='utf-8-sig')
arquivo8= pd.read_json("C:\\Users\Weirivelton\\Desktop\\Teste projetas\\Tratamento de dados\\Arquivos Json\\VRA_20215.json", encoding='utf-8-sig')
arquivo9= pd.read_json("C:\\Users\Weirivelton\\Desktop\\Teste projetas\\Tratamento de dados\\Arquivos Json\\VRA_20216.json", encoding='utf-8-sig')
arquivo10= pd.read_json("C:\\Users\Weirivelton\\Desktop\\Teste projetas\\Tratamento de dados\\Arquivos Json\\VRA_20217.json", encoding='utf-8-sig')
arquivo11= pd.read_json("C:\\Users\Weirivelton\\Desktop\\Teste projetas\\Tratamento de dados\\Arquivos Json\\VRA_20218.json", encoding='utf-8-sig')
arquivo12= pd.read_json("C:\\Users\Weirivelton\\Desktop\\Teste projetas\\Tratamento de dados\\Arquivos Json\\VRA_20219.json", encoding='utf-8-sig')

# %%
objs = [arquivo1,arquivo2,arquivo3,arquivo4,arquivo5,arquivo7,arquivo8,arquivo9,arquivo10,arquivo11,arquivo12]
arquivo = pd.concat(objs, axis=0)

# %%
arquivo.dropna(subset=['PartidaPrevista'], inplace=True)
arquivo.dropna(subset=['PartidaReal'], inplace=True)
arquivo.dropna(subset=['ChegadaPrevista'], inplace=True)
arquivo.dropna(subset=['ChegadaReal'], inplace=True)
arquivo.dropna(subset=['CódigoJustificativa'], inplace=True)

# %%
#Tratamento dos dados (Renomear colunas em snake_case)
arquivo.rename(columns={'ICAOEmpresaAérea': 'ICAO_IATA' ,   
                     'NúmeroVoo' :'Número_Voo',
                     'CódigoAutorização' :'Código_Autorização',
                    'CódigoTipoLinha' : 'Código_TipoLinha',
                    'ICAOAeródromoOrigem': 'ICAO_AeródromoOrigem',
                   'ICAOAeródromoDestino' : 'ICAO_AeródromoDestino',
                   'ChegadaPrevista': 'Chegada_Prevista',
                    'ChegadaReal' : 'Chegada_Real',
                    'SituaçãoVoo ' : 'Situação_Voo',
                    
                  
                   
                    }, inplace = True)

# %%
arquivo.to_csv("C:\\Users\\Weirivelton\Desktop\Teste projetas\\Tratamento de dados\\Bases tratadas\\var.csv" ,  encoding='utf-8')
